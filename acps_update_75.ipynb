# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import RobustScaler
import random
import tensorflow as tf
import re
import os

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv1D, Flatten, Dropout, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
#temp,dew,humidity,cloud_cover,solar_radiation,solar_energy, uv_radiation
# Define initial min and max values
min_val = [1000, 1000, 1000, 1000, 1000, 1000, 1000]
max_val = [-1000, -1000, -1000, -1000, -1000, -1000, -1000]

# %%
def adjust_dataframe_length(df, target_length):
    # Check if df.shape[0] is less than the target length
    if df.shape[0] < target_length:
        df = pd.concat([df, df.tail(target_length - df.shape[0])])

    # Check if df.shape[0] is greater than the target length
    if df.shape[0] > target_length:
        # Create a list of rows where the 4th column (precip) value is 0
        zero_precip_rows = []
        for i in range(len(df)):
            # if df.iloc[i, 3] == 0:
            zero_precip_rows.append(i)

        # Randomly select rows from the list of zero_precip_rows
        rows_to_remove = random.sample(zero_precip_rows, df.shape[0] - target_length)

        # Remove the selected rows from the DataFrame
        df = df.drop(rows_to_remove)
    return df

# Normalize the data using Min-Max scaling
def min_max_scaling(df, min_val, max_val):
    for i, col in enumerate(df.columns):
        df[col] = (df[col] - min_val[i]) / (max_val[i] - min_val[i])
    return df

def append_rows_to_single_row(df):
    # Normalize each column separately
    # Normalize the data using Min-Max scaling
    df_normalized = min_max_scaling(df, min_val, max_val)

    # Create an empty dictionary to store the data
    data_dict = {}

    # Number of days
    num_days = len(df_normalized)

    # Iterate over each row
    for i in range(num_days):
        # Get the data from the current row
        row_data = df_normalized.iloc[i].values

        # Append the data to the dictionary with modified column names
        for j, value in enumerate(row_data):
            column_name = f"{df_normalized.columns[j]}_day_{i+1}"
            data_dict[column_name] = value

    # Convert the dictionary to a DataFrame
    single_row_df = pd.DataFrame([data_dict])

    return single_row_df

def calculate_min_max(df):
    global min_val, max_val
    for i, col in enumerate(df.columns):
        min_val[i] = min(df[col].min(), min_val[i])
        max_val[i] = max(df[col].max(), max_val[i])


def load_and_adjust_data(urls, target_length):

    dfs = []

    for url in urls:
        # Read Excel file into DataFrame
        df = pd.read_excel(url)
        # Fill NaN values with column means
        df= df.drop(columns=['precip'])
        df = df.fillna(df.mean())
        if df.isna().any().any():
            print("NaN values encountered in DataFrame from URL:", url)
        #calculating for min max scaling
        calculate_min_max(df)
        # Adjust the length of the DataFrame
        df = adjust_dataframe_length(df, target_length)
        # Append the adjusted DataFrame to the list
        dfs.append(df)
    return dfs

def extract_label_from_url(url):

    filename = url.split('/')[-1]  # Get the filename from the URL
    label = re.split('_\d+', filename)[1]  # Extract the label based on the pattern
    return label[1:]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
mydrive_path = "/content/drive/MyDrive/ACPS_Project/Modified for model"

# List files in MyDrive with full paths
urls = [os.path.join(mydrive_path, file) for file in os.listdir(mydrive_path)]
print(urls)
# Out:
# ['/content/drive/MyDrive/ACPS_Project/Modified for model/Junagadh_2013_wheat_10-05_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Solan_2014_wheat_10-05_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Nandurbar_2011_wheat_10-05_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Davangere_2010_rice_01-09_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Thiruvarur_2014_rice_01-09_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Nizamabad_2012_wheat_10-05_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Karnal_2012_rice_01-09_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Nagaon_2015_rice_01-09_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Hanumangarh_2014_rice_01-09_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Chatra_2014_wheat_10-05_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Guntur_2014_jowar_01-08_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Udam Singh Nagar_2012_rice_01-09_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Junagadh_2010_jowar_01-08_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Idukki_2014_wheat_10-05_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Bargarh_2014_rice_01-09_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Hanumangarh_2013_rice_01-09_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Sonepur_2012_wheat_10-05_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Nadia_2013_wheat_10-05_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Raichur_2013_rice_01-09_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Udam Singh Nagar_2011_wheat_10-05_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Chatra_2013_wheat_10-05_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Ranchi_2012_rice_01-09_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Baghpat_2013_wheat_10-05_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Shahjahanpur_2012_rice_01-09_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Bargarh_2012_rice_01-09_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Dinajpur Dakshin_2012_wheat_10-05_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Janjgir-Champa_2012_rice_01-09_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Hapur_2012_wheat_10-05_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Chamba_2015_wheat_10-05_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Sambalpur_2012_wheat_10-05_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Nadia_2014_wheat_10-05_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Villupuram_2014_rice_01-09_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Indore_2012_wheat_10-05_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Junagadh_2010_wheat_10-05_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Rohtas_2015_rice_01-09_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Adilabad_2015_wheat_10-05_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Kokrajhar_2013_wheat_10-05_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Mahbubnagar_2011_wheat_10-05_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Kanker_2014_wheat_10-05_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Karnal_2013_rice_01-09_weather.xlsx', '/content/drive/MyDrive/ACPS_Project/Modified for model/Durg_2010_rice_01-09_weather.xlsx', '/content/drive/MyDrive/ACPS_Pro ...

# %%
labels = []
for url in urls:
  labels.append(extract_label_from_url(url))
# Load and adjust the data
dfs = load_and_adjust_data(urls, 180)

# Convert each DataFrame to a single row
single_row_dfs = [append_rows_to_single_row(df) for df in dfs]

# Concatenate the single-row DataFrames
df_concatenated = pd.concat(single_row_dfs, axis=0)

# %%
print(min_val)
print(max_val)
# Out:
# [-9.8, -18.2, 5.5, 0.0, 12.4, 1.1, 1]
# [41.9, 28.4, 99.8, 100.0, 403.6, 34.9, 10]

# %%
# Check if there are any NaN values in the DataFrame
if df_concatenated.isna().any().any():
    # Print the rows with NaN values
    print("Rows with NaN values:")
    print(df_concatenated[df_concatenated.isna().any(axis=1)])
# Drop rows with NaN values
df_concatenated = df_concatenated.dropna()

# Print the DataFrame after dropping rows
print(df_concatenated)
# Out:
#     temp_day_1  dew_day_1  humidity_day_1  cloudcover_day_1  \
# 0     0.705996   0.914163        0.869565             0.642
# 0     0.694391   0.783262        0.622481             0.311
# 0     0.682785   0.854077        0.794274             0.677
# 0     0.638298   0.785408        0.749735             0.383
# 0     0.680851   0.828326        0.737010             0.498
# ..         ...        ...             ...               ...
# 0     0.723404   0.879828        0.761400             0.639
# 0     0.713733   0.903433        0.829268             0.337
# 0     0.775629   0.858369        0.602333             0.738
# 0     0.820116   0.884120        0.582185             0.066
# 0     0.936170   0.581545        0.134677             0.463
#
#     solarradiation_day_1  solarenergy_day_1  uvindex_day_1  temp_day_2  \
# 0               0.619888           0.621302       0.888889    0.725338
# 0               0.405419           0.405325       0.555556    0.684720
# 0               0.613497           0.609467       0.888889    0.671180
# 0               0.418712           0.337278       0.555556    0.586074
# 0               0.525307           0.529586       0.777778    0.671180
# ..                   ...                ...            ...         ...
# 0               0.633947           0.636095       0.888889    0.754352
# 0               0.534509           0.532544       0.777778    0.731141
# 0               0.402863           0.405325       0.555556    0.769826
# 0               0.769172           0.766272       1.000000    0.816248
# 0               0.688139           0.686391       0.888889    0.926499
#
#     dew_day_2  humidity_day_2  ...  solarradiation_day_179  \
# 0    0.933476        0.865323  ...                0.793967
# 0    0.804721        0.671262  ...                0.744376
# 0    0.847639        0.809120  ...                0.777352
# 0    0.718884        0.733828  ...                0.603272
# 0    0.839056        0.782609  ...                0.277096
# ..        ...             ...  ...                     ...
# 0    0.886266        0.710498  ...                0.455521
# 0    0.886266        0.751856  ...                0.774540
# 0    0.851931        0.599152  ...                0.616309
# 0    0.881974        0.583245  ...                0.586656
# 0    0.682403        0.203606  ...                0.620654
#
#     solarenergy_day_179  uvindex_day_179  temp_day_180  dew_day_180  \
# 0              0.795858         1.000000      0.779497     0.888412
# 0              0.748521         1.000000      0.680851     0.658798
# 0              0.778107         1.000000      0.796905     0.761803
# 0              0.603550         0.888889      0.665377     0.826180
# 0              0.281065         0.333333      0.748549     0.901288
# ..                  ...              ...           ...          ...
# 0              0.452663         0.666667      0.593810     0.736052
# 0              0.772189         1.000000      0.818182     0.568670
# 0              0.615385         0.888889      0.595745     0.748927
# 0              0.588757         0.888889      0.669246     0.675966
# 0              0.618343         0.888889      0.584139     0.697425
#
#     humidity_day_180  cloudcover_day_180  solarradiation_day_180  \
# 0           0.658537               0.359                0.782464
# 0           0.435843               0.331                0.701431
# 0           0.465536               0.207                0.815695
# 0           0.777306               0.563                0.677914
# 0           0.735949               0.689                0.372955
# ..               ...                 ...                     ...
# 0           0.740191               0.000                0.458333
# 0           0.201485               0.092                0.763548
# 0           0.778367               0.467                0.633436
# 0           0.471898               0.446                0.563139
# 0           0.690350               0.687                0.587423
#
#     solarenergy_day_180  uvindex_day_180
# 0              0.784024         1.000000
# 0              0.701183         0.777778
# 0              0.807692         1.000000
# 0              0.677515         0.888889
# 0              0.378698         0.555556
# ..                  ...              ...
# 0              0.458580         0.666667
# 0              0.763314         1.000000
# 0              0.633136         0.888889
# 0              0.565089         0.777778
# 0              0.588757         0.888889
#
# [430 rows x 1260 columns]

# %%
#Split the data into train and test sets
X_train, X_test = train_test_split(df_concatenated.values, test_size=0.2, random_state=42)

# Further split the training data into train and validation sets
X_train, X_val = train_test_split(X_train, test_size=0.1, random_state=42)

# Reshape the data
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# Define the input layers
input_layer_train = Input(shape=(X_train.shape[1], X_train.shape[2]))
input_layer_test = Input(shape=(X_test.shape[1], X_test.shape[2]))
input_layer_val = Input(shape=(X_val.shape[1], X_val.shape[2]))

conv1 = Conv1D(512,kernel_size=3,activation='relu')(input_layer_train)
conv2 = Conv1D(512,kernel_size=3,activation='relu')(conv1)
conv3 = Conv1D(128,kernel_size=5,activation='relu')(conv2)
conv4 = Conv1D(128,kernel_size=5,activation='relu')(conv3)
flatten = Flatten()(conv4)

# Define the encoding layers
encoding_layer1 = Dense(512, activation='relu')(flatten)
encoding_layer2 = Dense(256, activation='relu')(encoding_layer1)
encoding_layer3 = Dense(128, activation='relu')(encoding_layer2)

# Define the decoding layers
#decoding_layer1 = Dense(128, activation='relu')(encoding_layer3)
decoding_layer2 = Dense(256, activation='relu')(encoding_layer3)
decoding_layer3 = Dense(512, activation='relu')(decoding_layer2)
decoding_layer4 = Dense(X_train.shape[1], activation='relu')(decoding_layer3)

# Define the autoencoder model
autoencoder = Model(inputs=input_layer_train, outputs=decoding_layer4)

# Compile the autoencoder
autoencoder.compile(optimizer='adam', loss='mean_absolute_error')

# Train the autoencoder on the training data
history = autoencoder.fit(X_train, X_train, epochs=1024, validation_data=(X_val, X_val))


# Evaluate the autoencoder on the test set
reconstruction_error_test = autoencoder.evaluate(X_test, X_test)
print("Reconstruction error on test set:", reconstruction_error_test)
# Out:
# Epoch 1/1024
# 10/10 [==============================] - 4s 148ms/step - loss: 0.5546 - val_loss: 0.4580
# Epoch 2/1024
# 10/10 [==============================] - 1s 110ms/step - loss: 0.3951 - val_loss: 0.3325
# Epoch 3/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.3388 - val_loss: 0.3222
# Epoch 4/1024
# 10/10 [==============================] - 1s 106ms/step - loss: 0.3232 - val_loss: 0.3136
# Epoch 5/1024
# 10/10 [==============================] - 1s 106ms/step - loss: 0.3182 - val_loss: 0.3127
# Epoch 6/1024
# 10/10 [==============================] - 1s 110ms/step - loss: 0.3172 - val_loss: 0.3099
# Epoch 7/1024
# 10/10 [==============================] - 1s 108ms/step - loss: 0.3169 - val_loss: 0.3114
# Epoch 8/1024
# 10/10 [==============================] - 1s 108ms/step - loss: 0.3166 - val_loss: 0.3100
# Epoch 9/1024
# 10/10 [==============================] - 1s 107ms/step - loss: 0.3157 - val_loss: 0.3110
# Epoch 10/1024
# 10/10 [==============================] - 1s 105ms/step - loss: 0.3153 - val_loss: 0.3092
# Epoch 11/1024
# 10/10 [==============================] - 1s 106ms/step - loss: 0.3151 - val_loss: 0.3102
# Epoch 12/1024
# 10/10 [==============================] - 1s 106ms/step - loss: 0.3152 - val_loss: 0.3104
# Epoch 13/1024
# 10/10 [==============================] - 1s 109ms/step - loss: 0.3160 - val_loss: 0.3082
# Epoch 14/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.3151 - val_loss: 0.3079
# Epoch 15/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.3140 - val_loss: 0.3066
# Epoch 16/1024
# 10/10 [==============================] - 1s 108ms/step - loss: 0.3114 - val_loss: 0.3024
# Epoch 17/1024
# 10/10 [==============================] - 1s 107ms/step - loss: 0.3040 - val_loss: 0.2931
# Epoch 18/1024
# 10/10 [==============================] - 1s 106ms/step - loss: 0.2927 - val_loss: 0.2782
# Epoch 19/1024
# 10/10 [==============================] - 1s 107ms/step - loss: 0.2748 - val_loss: 0.2689
# Epoch 20/1024
# 10/10 [==============================] - 1s 107ms/step - loss: 0.2814 - val_loss: 0.2544
# Epoch 21/1024
# 10/10 [==============================] - 1s 107ms/step - loss: 0.2584 - val_loss: 0.2470
# Epoch 22/1024
# 10/10 [==============================] - 1s 107ms/step - loss: 0.2505 - val_loss: 0.2439
# Epoch 23/1024
# 10/10 [==============================] - 1s 110ms/step - loss: 0.2489 - val_loss: 0.2408
# Epoch 24/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.2519 - val_loss: 0.2498
# Epoch 25/1024
# 10/10 [==============================] - 1s 109ms/step - loss: 0.2449 - val_loss: 0.2402
# Epoch 26/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.2442 - val_loss: 0.2420
# Epoch 27/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.2402 - val_loss: 0.2332
# Epoch 28/1024
# 10/10 [==============================] - 1s 110ms/step - loss: 0.2353 - val_loss: 0.2318
# Epoch 29/1024
# 10/10 [==============================] - 1s 107ms/step - loss: 0.2333 - val_loss: 0.2322
# Epoch 30/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.2325 - val_loss: 0.2301
# Epoch 31/1024
# 10/10 [==============================] - 1s 107ms/step - loss: 0.2306 - val_loss: 0.2283
# Epoch 32/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.2291 - val_loss: 0.2267
# Epoch 33/1024
# 10/10 [==============================] - 1s 107ms/step - loss: 0.2265 - val_loss: 0.2227
# Epoch 34/1024
# 10/10 [==============================] - 1s 107ms/step - loss: 0.2233 - val_loss: 0.2201
# Epoch 35/1024
# 10/10 [==============================] - 1s 107ms/step - loss: 0.2220 - val_loss: 0.2197
# Epoch 36/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.2197 - val_loss: 0.2180
# Epoch 37/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.2178 - val_loss: 0.2145
# Epoch 38/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.2148 - val_loss: 0.2131
# Epoch 39/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.2151 - val_loss: 0.2146
# Epoch 40/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.2140 - val_loss: 0.2096
# Epoch 41/1024
# 10/10 [==============================] - 1s 108ms/step - loss: 0.2106 - val_loss: 0.2087
# Epoch 42/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.2103 - val_loss: 0.2058
# Epoch 43/1024
# 10/10 [==============================] - 1s 109ms/step - loss: 0.2036 - val_loss: 0.2044
# Epoch 44/1024
# 10/10 [==============================] - 1s 108ms/step - loss: 0.2026 - val_loss: 0.2025
# Epoch 45/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.1996 - val_loss: 0.2030
# Epoch 46/1024
# 10/10 [==============================] - 1s 108ms/step - loss: 0.1986 - val_loss: 0.1979
# Epoch 47/1024
# 10/10 [==============================] - 1s 109ms/step - loss: 0.1955 - val_loss: 0.1955
# Epoch 48/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.1985 - val_loss: 0.2103
# Epoch 49/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.1974 - val_loss: 0.1940
# Epoch 50/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.1903 - val_loss: 0.1925
# Epoch 51/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.1888 - val_loss: 0.1905
# Epoch 52/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.1874 - val_loss: 0.1896
# Epoch 53/1024
# 10/10 [==============================] - 1s 109ms/step - loss: 0.1862 - val_loss: 0.1872
# Epoch 54/1024
# 10/10 [==============================] - 1s 109ms/step - loss: 0.1845 - val_loss: 0.1877
# Epoch 55/1024
# 10/10 [==============================] - 1s 109ms/step - loss: 0.1843 - val_loss: 0.1863
# Epoch 56/1024
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1828 - val_loss: 0.1869
# Epoch 57/1024
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1813 - val_loss: 0.1832
# Epoch 58/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1804 - val_loss: 0.1834
# Epoch 59/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.1807 - val_loss: 0.1819
# Epoch 60/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.1791 - val_loss: 0.1822
# Epoch 61/1024
# 10/10 [==============================] - 1s 109ms/step - loss: 0.1773 - val_loss: 0.1777
# Epoch 62/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.1744 - val_loss: 0.1773
# Epoch 63/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.1741 - val_loss: 0.1771
# Epoch 64/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.1713 - val_loss: 0.1772
# Epoch 65/1024
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1711 - val_loss: 0.1773
# Epoch 66/1024
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1715 - val_loss: 0.1743
# Epoch 67/1024
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1707 - val_loss: 0.1735
# Epoch 68/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.1683 - val_loss: 0.1702
# Epoch 69/1024
# 10/10 [==============================] - 1s 109ms/step - loss: 0.1716 - val_loss: 0.1739
# Epoch 70/1024
# 10/10 [==============================] - 1s 109ms/step - loss: 0.1706 - val_loss: 0.1695
# Epoch 71/1024
# 10/10 [==============================] - 1s 109ms/step - loss: 0.1670 - val_loss: 0.1662
# Epoch 72/1024
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1631 - val_loss: 0.1670
# Epoch 73/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.1612 - val_loss: 0.1643
# Epoch 74/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.1587 - val_loss: 0.1636
# Epoch 75/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.1564 - val_loss: 0.1617
# Epoch 76/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.1550 - val_loss: 0.1609
# Epoch 77/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1555 - val_loss: 0.1606
# Epoch 78/1024
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1550 - val_loss: 0.1602
# Epoch 79/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1536 - val_loss: 0.1590
# Epoch 80/1024
# 10/10 [==============================] - 1s 109ms/step - loss: 0.1548 - val_loss: 0.1582
# Epoch 81/1024
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1576 - val_loss: 0.1597
# Epoch 82/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.1534 - val_loss: 0.1593
# Epoch 83/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.1507 - val_loss: 0.1583
# Epoch 84/1024
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1499 - val_loss: 0.1547
# Epoch 85/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.1463 - val_loss: 0.1540
# Epoch 86/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.1454 - val_loss: 0.1527
# Epoch 87/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.1445 - val_loss: 0.1530
# Epoch 88/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.1463 - val_loss: 0.1570
# Epoch 89/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.1481 - val_loss: 0.1524
# Epoch 90/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1462 - val_loss: 0.1551
# Epoch 91/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1479 - val_loss: 0.1536
# Epoch 92/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1442 - val_loss: 0.1516
# Epoch 93/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1412 - val_loss: 0.1495
# Epoch 94/1024
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1402 - val_loss: 0.1487
# Epoch 95/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1387 - val_loss: 0.1484
# Epoch 96/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1379 - val_loss: 0.1460
# Epoch 97/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.1373 - val_loss: 0.1446
# Epoch 98/1024
# 10/10 [==============================] - 1s 117ms/step - loss: 0.1391 - val_loss: 0.1463
# Epoch 99/1024
# 10/10 [==============================] - 1s 117ms/step - loss: 0.1354 - val_loss: 0.1442
# Epoch 100/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.1333 - val_loss: 0.1419
# Epoch 101/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1321 - val_loss: 0.1409
# Epoch 102/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1309 - val_loss: 0.1405
# Epoch 103/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1297 - val_loss: 0.1413
# Epoch 104/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1304 - val_loss: 0.1404
# Epoch 105/1024
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1296 - val_loss: 0.1402
# Epoch 106/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1293 - val_loss: 0.1412
# Epoch 107/1024
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1306 - val_loss: 0.1400
# Epoch 108/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.1323 - val_loss: 0.1391
# Epoch 109/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1294 - val_loss: 0.1400
# Epoch 110/1024
# 10/10 [==============================] - 1s 117ms/step - loss: 0.1271 - val_loss: 0.1375
# Epoch 111/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.1247 - val_loss: 0.1352
# Epoch 112/1024
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1246 - val_loss: 0.1342
# Epoch 113/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1223 - val_loss: 0.1327
# Epoch 114/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1213 - val_loss: 0.1328
# Epoch 115/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1215 - val_loss: 0.1341
# Epoch 116/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1208 - val_loss: 0.1338
# Epoch 117/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1217 - val_loss: 0.1354
# Epoch 118/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1233 - val_loss: 0.1361
# Epoch 119/1024
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1212 - val_loss: 0.1312
# Epoch 120/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1191 - val_loss: 0.1312
# Epoch 121/1024
# 10/10 [==============================] - 1s 117ms/step - loss: 0.1169 - val_loss: 0.1288
# Epoch 122/1024
# 10/10 [==============================] - 1s 117ms/step - loss: 0.1156 - val_loss: 0.1287
# Epoch 123/1024
# 10/10 [==============================] - 1s 118ms/step - loss: 0.1152 - val_loss: 0.1282
# Epoch 124/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1155 - val_loss: 0.1279
# Epoch 125/1024
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1143 - val_loss: 0.1267
# Epoch 126/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.1126 - val_loss: 0.1275
# Epoch 127/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.1139 - val_loss: 0.1273
# Epoch 128/1024
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1144 - val_loss: 0.1283
# Epoch 129/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.1134 - val_loss: 0.1260
# Epoch 130/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.1127 - val_loss: 0.1261
# Epoch 131/1024
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1113 - val_loss: 0.1245
# Epoch 132/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.1095 - val_loss: 0.1239
# Epoch 133/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.1101 - val_loss: 0.1226
# Epoch 134/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.1072 - val_loss: 0.1243
# Epoch 135/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1077 - val_loss: 0.1226
# Epoch 136/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1076 - val_loss: 0.1221
# Epoch 137/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.1113 - val_loss: 0.1237
# Epoch 138/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.1084 - val_loss: 0.1213
# Epoch 139/1024
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1062 - val_loss: 0.1207
# Epoch 140/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.1062 - val_loss: 0.1217
# Epoch 141/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1047 - val_loss: 0.1191
# Epoch 142/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.1041 - val_loss: 0.1185
# Epoch 143/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.1018 - val_loss: 0.1178
# Epoch 144/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.1008 - val_loss: 0.1172
# Epoch 145/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.1005 - val_loss: 0.1167
# Epoch 146/1024
# 10/10 [==============================] - 1s 119ms/step - loss: 0.0991 - val_loss: 0.1170
# Epoch 147/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.1006 - val_loss: 0.1177
# Epoch 148/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0992 - val_loss: 0.1162
# Epoch 149/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0983 - val_loss: 0.1174
# Epoch 150/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0996 - val_loss: 0.1168
# Epoch 151/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0990 - val_loss: 0.1165
# Epoch 152/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0979 - val_loss: 0.1178
# Epoch 153/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0988 - val_loss: 0.1171
# Epoch 154/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0985 - val_loss: 0.1166
# Epoch 155/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0986 - val_loss: 0.1166
# Epoch 156/1024
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0996 - val_loss: 0.1170
# Epoch 157/1024
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0989 - val_loss: 0.1161
# Epoch 158/1024
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0986 - val_loss: 0.1173
# Epoch 159/1024
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0982 - val_loss: 0.1159
# Epoch 160/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0991 - val_loss: 0.1149
# Epoch 161/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0972 - val_loss: 0.1158
# Epoch 162/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0960 - val_loss: 0.1137
# Epoch 163/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0934 - val_loss: 0.1139
# Epoch 164/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0938 - val_loss: 0.1123
# Epoch 165/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0923 - val_loss: 0.1126
# Epoch 166/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0921 - val_loss: 0.1131
# Epoch 167/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0915 - val_loss: 0.1125
# Epoch 168/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0917 - val_loss: 0.1124
# Epoch 169/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0915 - val_loss: 0.1126
# Epoch 170/1024
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0906 - val_loss: 0.1114
# Epoch 171/1024
# 10/10 [==============================] - 1s 119ms/step - loss: 0.0918 - val_loss: 0.1127
# Epoch 172/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0911 - val_loss: 0.1114
# Epoch 173/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0907 - val_loss: 0.1108
# Epoch 174/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0909 - val_loss: 0.1115
# Epoch 175/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0896 - val_loss: 0.1103
# Epoch 176/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0891 - val_loss: 0.1111
# Epoch 177/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0896 - val_loss: 0.1165
# Epoch 178/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0921 - val_loss: 0.1149
# Epoch 179/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0925 - val_loss: 0.1114
# Epoch 180/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0902 - val_loss: 0.1103
# Epoch 181/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0885 - val_loss: 0.1105
# Epoch 182/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0871 - val_loss: 0.1089
# Epoch 183/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0865 - val_loss: 0.1092
# Epoch 184/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0868 - val_loss: 0.1091
# Epoch 185/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0878 - val_loss: 0.1138
# Epoch 186/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0882 - val_loss: 0.1098
# Epoch 187/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0866 - val_loss: 0.1071
# Epoch 188/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0840 - val_loss: 0.1070
# Epoch 189/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0828 - val_loss: 0.1059
# Epoch 190/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0817 - val_loss: 0.1063
# Epoch 191/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0810 - val_loss: 0.1054
# Epoch 192/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0807 - val_loss: 0.1053
# Epoch 193/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0813 - val_loss: 0.1060
# Epoch 194/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0818 - val_loss: 0.1083
# Epoch 195/1024
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0831 - val_loss: 0.1066
# Epoch 196/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0835 - val_loss: 0.1064
# Epoch 197/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0828 - val_loss: 0.1051
# Epoch 198/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0816 - val_loss: 0.1058
# Epoch 199/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0803 - val_loss: 0.1037
# Epoch 200/1024
# 10/10 [==============================] - 1s 121ms/step - loss: 0.0791 - val_loss: 0.1038
# Epoch 201/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0788 - val_loss: 0.1061
# Epoch 202/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0797 - val_loss: 0.1038
# Epoch 203/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0785 - val_loss: 0.1042
# Epoch 204/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0791 - val_loss: 0.1040
# Epoch 205/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0815 - val_loss: 0.1040
# Epoch 206/1024
# 10/10 [==============================] - 1s 120ms/step - loss: 0.0799 - val_loss: 0.1038
# Epoch 207/1024
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0772 - val_loss: 0.1035
# Epoch 208/1024
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0766 - val_loss: 0.1046
# Epoch 209/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0765 - val_loss: 0.1026
# Epoch 210/1024
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0755 - val_loss: 0.1037
# Epoch 211/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0757 - val_loss: 0.1019
# Epoch 212/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0744 - val_loss: 0.1015
# Epoch 213/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0736 - val_loss: 0.1016
# Epoch 214/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0732 - val_loss: 0.1012
# Epoch 215/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0728 - val_loss: 0.1024
# Epoch 216/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0728 - val_loss: 0.1014
# Epoch 217/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0747 - val_loss: 0.1008
# Epoch 218/1024
# 10/10 [==============================] - 1s 120ms/step - loss: 0.0760 - val_loss: 0.1007
# Epoch 219/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0766 - val_loss: 0.1025
# Epoch 220/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0753 - val_loss: 0.0997
# Epoch 221/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0733 - val_loss: 0.1005
# Epoch 222/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0721 - val_loss: 0.0993
# Epoch 223/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0719 - val_loss: 0.1002
# Epoch 224/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0720 - val_loss: 0.1004
# Epoch 225/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0715 - val_loss: 0.1014
# Epoch 226/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0723 - val_loss: 0.1005
# Epoch 227/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0715 - val_loss: 0.1001
# Epoch 228/1024
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0714 - val_loss: 0.1008
# Epoch 229/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0712 - val_loss: 0.1004
# Epoch 230/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0705 - val_loss: 0.1004
# Epoch 231/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0702 - val_loss: 0.0987
# Epoch 232/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0691 - val_loss: 0.0993
# Epoch 233/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0679 - val_loss: 0.0973
# Epoch 234/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0666 - val_loss: 0.0976
# Epoch 235/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0667 - val_loss: 0.0977
# Epoch 236/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0670 - val_loss: 0.0974
# Epoch 237/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0665 - val_loss: 0.0976
# Epoch 238/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0665 - val_loss: 0.0973
# Epoch 239/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0671 - val_loss: 0.0973
# Epoch 240/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0680 - val_loss: 0.0968
# Epoch 241/1024
# 10/10 [==============================] - 1s 119ms/step - loss: 0.0657 - val_loss: 0.0978
# Epoch 242/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0657 - val_loss: 0.0969
# Epoch 243/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0660 - val_loss: 0.0979
# Epoch 244/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0655 - val_loss: 0.0966
# Epoch 245/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0645 - val_loss: 0.0963
# Epoch 246/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0643 - val_loss: 0.0959
# Epoch 247/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0645 - val_loss: 0.0961
# Epoch 248/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0633 - val_loss: 0.0957
# Epoch 249/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0630 - val_loss: 0.0960
# Epoch 250/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0634 - val_loss: 0.0959
# Epoch 251/1024
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0636 - val_loss: 0.0959
# Epoch 252/1024
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0628 - val_loss: 0.0956
# Epoch 253/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0621 - val_loss: 0.0956
# Epoch 254/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0620 - val_loss: 0.0954
# Epoch 255/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0629 - val_loss: 0.0948
# Epoch 256/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0629 - val_loss: 0.0954
# Epoch 257/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0639 - val_loss: 0.0962
# Epoch 258/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0624 - val_loss: 0.0952
# Epoch 259/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0621 - val_loss: 0.0955
# Epoch 260/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0618 - val_loss: 0.0946
# Epoch 261/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0604 - val_loss: 0.0941
# Epoch 262/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0599 - val_loss: 0.0936
# Epoch 263/1024
# 10/10 [==============================] - 1s 119ms/step - loss: 0.0595 - val_loss: 0.0933
# Epoch 264/1024
# 10/10 [==============================] - 1s 119ms/step - loss: 0.0596 - val_loss: 0.0936
# Epoch 265/1024
# 10/10 [==============================] - 1s 119ms/step - loss: 0.0593 - val_loss: 0.0938
# Epoch 266/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0601 - val_loss: 0.0934
# Epoch 267/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0595 - val_loss: 0.0937
# Epoch 268/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0590 - val_loss: 0.0943
# Epoch 269/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0597 - val_loss: 0.0948
# Epoch 270/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0605 - val_loss: 0.0951
# Epoch 271/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0613 - val_loss: 0.0938
# Epoch 272/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0616 - val_loss: 0.0939
# Epoch 273/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0614 - val_loss: 0.0965
# Epoch 274/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0610 - val_loss: 0.0949
# Epoch 275/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0598 - val_loss: 0.0941
# Epoch 276/1024
# 10/10 [==============================] - 1s 119ms/step - loss: 0.0592 - val_loss: 0.0945
# Epoch 277/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0587 - val_loss: 0.0941
# Epoch 278/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0591 - val_loss: 0.0950
# Epoch 279/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0603 - val_loss: 0.0946
# Epoch 280/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0581 - val_loss: 0.0932
# Epoch 281/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0572 - val_loss: 0.0934
# Epoch 282/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0570 - val_loss: 0.0940
# Epoch 283/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0567 - val_loss: 0.0929
# Epoch 284/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0564 - val_loss: 0.0934
# Epoch 285/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0565 - val_loss: 0.0933
# Epoch 286/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0560 - val_loss: 0.0936
# Epoch 287/1024
# 10/10 [==============================] - 1s 120ms/step - loss: 0.0565 - val_loss: 0.0930
# Epoch 288/1024
# 10/10 [==============================] - 1s 119ms/step - loss: 0.0561 - val_loss: 0.0933
# Epoch 289/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0573 - val_loss: 0.0940
# Epoch 290/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0571 - val_loss: 0.0940
# Epoch 291/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0578 - val_loss: 0.0959
# Epoch 292/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0579 - val_loss: 0.0942
# Epoch 293/1024
# 10/10 [==============================] - 1s 121ms/step - loss: 0.0566 - val_loss: 0.0934
# Epoch 294/1024
# 10/10 [==============================] - 1s 128ms/step - loss: 0.0557 - val_loss: 0.0923
# Epoch 295/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0565 - val_loss: 0.0941
# Epoch 296/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0564 - val_loss: 0.0933
# Epoch 297/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0590 - val_loss: 0.0940
# Epoch 298/1024
# 10/10 [==============================] - 1s 121ms/step - loss: 0.0583 - val_loss: 0.0957
# Epoch 299/1024
# 10/10 [==============================] - 1s 119ms/step - loss: 0.0597 - val_loss: 0.0943
# Epoch 300/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0580 - val_loss: 0.0962
# Epoch 301/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0582 - val_loss: 0.0941
# Epoch 302/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0556 - val_loss: 0.0931
# Epoch 303/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0571 - val_loss: 0.0939
# Epoch 304/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0585 - val_loss: 0.0929
# Epoch 305/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0552 - val_loss: 0.0928
# Epoch 306/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0550 - val_loss: 0.0926
# Epoch 307/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0580 - val_loss: 0.0944
# Epoch 308/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0589 - val_loss: 0.0941
# Epoch 309/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0571 - val_loss: 0.0942
# Epoch 310/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0571 - val_loss: 0.0925
# Epoch 311/1024
# 10/10 [==============================] - 1s 121ms/step - loss: 0.0545 - val_loss: 0.0927
# Epoch 312/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0531 - val_loss: 0.0921
# Epoch 313/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0530 - val_loss: 0.0920
# Epoch 314/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0546 - val_loss: 0.0933
# Epoch 315/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0542 - val_loss: 0.0928
# Epoch 316/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0536 - val_loss: 0.0923
# Epoch 317/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0534 - val_loss: 0.0925
# Epoch 318/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0535 - val_loss: 0.0921
# Epoch 319/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0542 - val_loss: 0.0921
# Epoch 320/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0533 - val_loss: 0.0924
# Epoch 321/1024
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0523 - val_loss: 0.0920
# Epoch 322/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0512 - val_loss: 0.0926
# Epoch 323/1024
# 10/10 [==============================] - 1s 120ms/step - loss: 0.0510 - val_loss: 0.0920
# Epoch 324/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0522 - val_loss: 0.0931
# Epoch 325/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0518 - val_loss: 0.0942
# Epoch 326/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0527 - val_loss: 0.0935
# Epoch 327/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0525 - val_loss: 0.0932
# Epoch 328/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0518 - val_loss: 0.0921
# Epoch 329/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0507 - val_loss: 0.0914
# Epoch 330/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0518 - val_loss: 0.0934
# Epoch 331/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0516 - val_loss: 0.0916
# Epoch 332/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0503 - val_loss: 0.0917
# Epoch 333/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0515 - val_loss: 0.0921
# Epoch 334/1024
# 10/10 [==============================] - 1s 120ms/step - loss: 0.0522 - val_loss: 0.0932
# Epoch 335/1024
# 10/10 [==============================] - 1s 119ms/step - loss: 0.0523 - val_loss: 0.0919
# Epoch 336/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0520 - val_loss: 0.0919
# Epoch 337/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0526 - val_loss: 0.0941
# Epoch 338/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0526 - val_loss: 0.0921
# Epoch 339/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0512 - val_loss: 0.0926
# Epoch 340/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0505 - val_loss: 0.0919
# Epoch 341/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0503 - val_loss: 0.0917
# Epoch 342/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0498 - val_loss: 0.0925
# Epoch 343/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0507 - val_loss: 0.0940
# Epoch 344/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0518 - val_loss: 0.0926
# Epoch 345/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0536 - val_loss: 0.0939
# Epoch 346/1024
# 10/10 [==============================] - 1s 119ms/step - loss: 0.0520 - val_loss: 0.0928
# Epoch 347/1024
# 10/10 [==============================] - 1s 120ms/step - loss: 0.0503 - val_loss: 0.0929
# Epoch 348/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0501 - val_loss: 0.0919
# Epoch 349/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0491 - val_loss: 0.0922
# Epoch 350/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0486 - val_loss: 0.0919
# Epoch 351/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0486 - val_loss: 0.0925
# Epoch 352/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0486 - val_loss: 0.0924
# Epoch 353/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0493 - val_loss: 0.0924
# Epoch 354/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0487 - val_loss: 0.0920
# Epoch 355/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0488 - val_loss: 0.0931
# Epoch 356/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0496 - val_loss: 0.0925
# Epoch 357/1024
# 10/10 [==============================] - 1s 119ms/step - loss: 0.0495 - val_loss: 0.0929
# Epoch 358/1024
# 10/10 [==============================] - 1s 119ms/step - loss: 0.0499 - val_loss: 0.0926
# Epoch 359/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0495 - val_loss: 0.0922
# Epoch 360/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0488 - val_loss: 0.0932
# Epoch 361/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0486 - val_loss: 0.0928
# Epoch 362/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0484 - val_loss: 0.0937
# Epoch 363/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0485 - val_loss: 0.0922
# Epoch 364/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0480 - val_loss: 0.0934
# Epoch 365/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0482 - val_loss: 0.0940
# Epoch 366/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0489 - val_loss: 0.0954
# Epoch 367/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0503 - val_loss: 0.0940
# Epoch 368/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0527 - val_loss: 0.0948
# Epoch 369/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0523 - val_loss: 0.0923
# Epoch 370/1024
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0508 - val_loss: 0.0926
# Epoch 371/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0499 - val_loss: 0.0931
# Epoch 372/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0487 - val_loss: 0.0920
# Epoch 373/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0477 - val_loss: 0.0915
# Epoch 374/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0468 - val_loss: 0.0922
# Epoch 375/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0467 - val_loss: 0.0920
# Epoch 376/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0466 - val_loss: 0.0919
# Epoch 377/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0465 - val_loss: 0.0922
# Epoch 378/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0474 - val_loss: 0.0927
# Epoch 379/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0475 - val_loss: 0.0923
# Epoch 380/1024
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0479 - val_loss: 0.0918
# Epoch 381/1024
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0472 - val_loss: 0.0927
# Epoch 382/1024
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0475 - val_loss: 0.0919
# Epoch 383/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0467 - val_loss: 0.0930
# Epoch 384/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0495 - val_loss: 0.0958
# Epoch 385/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0477 - val_loss: 0.0920
# Epoch 386/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0470 - val_loss: 0.0930
# Epoch 387/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0471 - val_loss: 0.0924
# Epoch 388/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0469 - val_loss: 0.0931
# Epoch 389/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0474 - val_loss: 0.0922
# Epoch 390/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0464 - val_loss: 0.0924
# Epoch 391/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0454 - val_loss: 0.0921
# Epoch 392/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0457 - val_loss: 0.0923
# Epoch 393/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0454 - val_loss: 0.0920
# Epoch 394/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0456 - val_loss: 0.0925
# Epoch 395/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0463 - val_loss: 0.0918
# Epoch 396/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0466 - val_loss: 0.0934
# Epoch 397/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0462 - val_loss: 0.0930
# Epoch 398/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0464 - val_loss: 0.0923
# Epoch 399/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0451 - val_loss: 0.0919
# Epoch 400/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0444 - val_loss: 0.0921
# Epoch 401/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0447 - val_loss: 0.0920
# Epoch 402/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0443 - val_loss: 0.0920
# Epoch 403/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0443 - val_loss: 0.0921
# Epoch 404/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0445 - val_loss: 0.0932
# Epoch 405/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0445 - val_loss: 0.0933
# Epoch 406/1024
# 10/10 [==============================] - 1s 120ms/step - loss: 0.0464 - val_loss: 0.0927
# Epoch 407/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0465 - val_loss: 0.0925
# Epoch 408/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0461 - val_loss: 0.0923
# Epoch 409/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0447 - val_loss: 0.0911
# Epoch 410/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0445 - val_loss: 0.0916
# Epoch 411/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0440 - val_loss: 0.0909
# Epoch 412/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0435 - val_loss: 0.0922
# Epoch 413/1024
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0429 - val_loss: 0.0916
# Epoch 414/1024
# 10/10 [==============================] - 1s 120ms/step - loss: 0.0425 - val_loss: 0.0913
# Epoch 415/1024
# 10/10 [==============================] - 1s 120ms/step - loss: 0.0427 - val_loss: 0.0927
# Epoch 416/1024
# 10/10 [==============================] - 1s 120ms/step - loss: 0.0445 - val_loss: 0.0943
# Epoch 417/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0451 - val_loss: 0.0919
# Epoch 418/1024
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0440 - val_loss: 0.0924
# Epoch 419/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0446 - val_loss: 0.0915
# Epoch 420/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0441 - val_loss: 0.0917
# Epoch 421/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0435 - val_loss: 0.0915
# Epoch 422/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0428 - val_loss: 0.0906
# Epoch 423/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0438 - val_loss: 0.0921
# Epoch 424/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0467 - val_loss: 0.0954
# Epoch 425/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0467 - val_loss: 0.0924
# Epoch 426/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0449 - val_loss: 0.0927
# Epoch 427/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0442 - val_loss: 0.0920
# Epoch 428/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0431 - val_loss: 0.0916
# Epoch 429/1024
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0433 - val_loss: 0.0924
# Epoch 430/1024
# 10/10 [==============================] - 1s 119ms/step - loss: 0.0434 - val_loss: 0.0918
# Epoch 431/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0429 - val_loss: 0.0914
# Epoch 432/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0429 - val_loss: 0.0935
# Epoch 433/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0434 - val_loss: 0.0920
# Epoch 434/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0433 - val_loss: 0.0919
# Epoch 435/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0434 - val_loss: 0.0923
# Epoch 436/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0427 - val_loss: 0.0919
# Epoch 437/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0418 - val_loss: 0.0917
# Epoch 438/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0416 - val_loss: 0.0918
# Epoch 439/1024
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0416 - val_loss: 0.0914
# Epoch 440/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0415 - val_loss: 0.0925
# Epoch 441/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0417 - val_loss: 0.0913
# Epoch 442/1024
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0414 - val_loss: 0.0921
# Epoch 443/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0407 - val_loss: 0.0911
# Epoch 444/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0411 - val_loss: 0.0920
# Epoch 445/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0407 - val_loss: 0.0906
# Epoch 446/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0407 - val_loss: 0.0927
# Epoch 447/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0409 - val_loss: 0.0916
# Epoch 448/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0405 - val_loss: 0.0926
# Epoch 449/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0411 - val_loss: 0.0922
# Epoch 450/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0423 - val_loss: 0.0931
# Epoch 451/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0430 - val_loss: 0.0929
# Epoch 452/1024
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0424 - val_loss: 0.0925
# Epoch 453/1024
# 10/10 [==============================] - 1s 120ms/step - loss: 0.0417 - val_loss: 0.0941
# Epoch 454/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0414 - val_loss: 0.0918
# Epoch 455/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0409 - val_loss: 0.0918
# Epoch 456/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0405 - val_loss: 0.0916
# Epoch 457/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0417 - val_loss: 0.0934
# Epoch 458/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0464 - val_loss: 0.0943
# Epoch 459/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0453 - val_loss: 0.0929
# Epoch 460/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0444 - val_loss: 0.0928
# Epoch 461/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0420 - val_loss: 0.0919
# Epoch 462/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0412 - val_loss: 0.0922
# Epoch 463/1024
# ...
# Epoch 873/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0239 - val_loss: 0.0925
# Epoch 874/1024
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0242 - val_loss: 0.0920
# Epoch 875/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0235 - val_loss: 0.0920
# Epoch 876/1024
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0231 - val_loss: 0.0916
# Epoch 877/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0230 - val_loss: 0.0922
# Epoch 878/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0230 - val_loss: 0.0923
# Epoch 879/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0235 - val_loss: 0.0926
# Epoch 880/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0236 - val_loss: 0.0921
# Epoch 881/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0233 - val_loss: 0.0922
# Epoch 882/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0230 - val_loss: 0.0921
# Epoch 883/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0231 - val_loss: 0.0920
# Epoch 884/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0229 - val_loss: 0.0921
# Epoch 885/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0239 - val_loss: 0.0923
# Epoch 886/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0234 - val_loss: 0.0925
# Epoch 887/1024
# 10/10 [==============================] - 1s 120ms/step - loss: 0.0236 - val_loss: 0.0920
# Epoch 888/1024
# 10/10 [==============================] - 1s 120ms/step - loss: 0.0241 - val_loss: 0.0921
# Epoch 889/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0236 - val_loss: 0.0929
# Epoch 890/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0251 - val_loss: 0.0920
# Epoch 891/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0249 - val_loss: 0.0930
# Epoch 892/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0255 - val_loss: 0.0923
# Epoch 893/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0255 - val_loss: 0.0922
# Epoch 894/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0256 - val_loss: 0.0929
# Epoch 895/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0253 - val_loss: 0.0922
# Epoch 896/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0249 - val_loss: 0.0925
# Epoch 897/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0247 - val_loss: 0.0923
# Epoch 898/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0247 - val_loss: 0.0921
# Epoch 899/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0239 - val_loss: 0.0917
# Epoch 900/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0234 - val_loss: 0.0924
# Epoch 901/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0234 - val_loss: 0.0922
# Epoch 902/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0229 - val_loss: 0.0923
# Epoch 903/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0229 - val_loss: 0.0923
# Epoch 904/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0233 - val_loss: 0.0919
# Epoch 905/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0235 - val_loss: 0.0926
# Epoch 906/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0244 - val_loss: 0.0926
# Epoch 907/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0236 - val_loss: 0.0926
# Epoch 908/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0235 - val_loss: 0.0918
# Epoch 909/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0227 - val_loss: 0.0924
# Epoch 910/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0228 - val_loss: 0.0923
# Epoch 911/1024
# 10/10 [==============================] - 1s 119ms/step - loss: 0.0230 - val_loss: 0.0925
# Epoch 912/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0227 - val_loss: 0.0921
# Epoch 913/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0223 - val_loss: 0.0918
# Epoch 914/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0225 - val_loss: 0.0930
# Epoch 915/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0229 - val_loss: 0.0921
# Epoch 916/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0225 - val_loss: 0.0922
# Epoch 917/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0221 - val_loss: 0.0922
# Epoch 918/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0221 - val_loss: 0.0920
# Epoch 919/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0223 - val_loss: 0.0925
# Epoch 920/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0227 - val_loss: 0.0925
# Epoch 921/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0230 - val_loss: 0.0924
# Epoch 922/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0226 - val_loss: 0.0919
# Epoch 923/1024
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0223 - val_loss: 0.0928
# Epoch 924/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0224 - val_loss: 0.0921
# Epoch 925/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0222 - val_loss: 0.0931
# Epoch 926/1024
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0227 - val_loss: 0.0923
# Epoch 927/1024
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0225 - val_loss: 0.0921
# Epoch 928/1024
# 10/10 [==============================] - 1s 120ms/step - loss: 0.0223 - val_loss: 0.0922
# Epoch 929/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0224 - val_loss: 0.0926
# Epoch 930/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0235 - val_loss: 0.0926
# Epoch 931/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0238 - val_loss: 0.0931
# Epoch 932/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0236 - val_loss: 0.0921
# Epoch 933/1024
# 10/10 [==============================] - 1s 119ms/step - loss: 0.0233 - val_loss: 0.0929
# Epoch 934/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0226 - val_loss: 0.0922
# Epoch 935/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0234 - val_loss: 0.0928
# Epoch 936/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0235 - val_loss: 0.0923
# Epoch 937/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0230 - val_loss: 0.0928
# Epoch 938/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0227 - val_loss: 0.0925
# Epoch 939/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0228 - val_loss: 0.0925
# Epoch 940/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0231 - val_loss: 0.0926
# Epoch 941/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0220 - val_loss: 0.0927
# Epoch 942/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0218 - val_loss: 0.0924
# Epoch 943/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0215 - val_loss: 0.0925
# Epoch 944/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0214 - val_loss: 0.0929
# Epoch 945/1024
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0214 - val_loss: 0.0925
# Epoch 946/1024
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0214 - val_loss: 0.0926
# Epoch 947/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0215 - val_loss: 0.0922
# Epoch 948/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0214 - val_loss: 0.0926
# Epoch 949/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0211 - val_loss: 0.0925
# Epoch 950/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0210 - val_loss: 0.0923
# Epoch 951/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0213 - val_loss: 0.0928
# Epoch 952/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0219 - val_loss: 0.0926
# Epoch 953/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0214 - val_loss: 0.0923
# Epoch 954/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0213 - val_loss: 0.0925
# Epoch 955/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0217 - val_loss: 0.0931
# Epoch 956/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0223 - val_loss: 0.0925
# Epoch 957/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0226 - val_loss: 0.0925
# Epoch 958/1024
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0220 - val_loss: 0.0928
# Epoch 959/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0228 - val_loss: 0.0931
# Epoch 960/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0230 - val_loss: 0.0921
# Epoch 961/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0225 - val_loss: 0.0930
# Epoch 962/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0233 - val_loss: 0.0919
# Epoch 963/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0232 - val_loss: 0.0925
# Epoch 964/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0228 - val_loss: 0.0933
# Epoch 965/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0240 - val_loss: 0.0924
# Epoch 966/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0236 - val_loss: 0.0931
# Epoch 967/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0235 - val_loss: 0.0923
# Epoch 968/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0236 - val_loss: 0.0928
# Epoch 969/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0234 - val_loss: 0.0924
# Epoch 970/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0239 - val_loss: 0.0930
# Epoch 971/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0235 - val_loss: 0.0928
# Epoch 972/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0225 - val_loss: 0.0926
# Epoch 973/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0222 - val_loss: 0.0922
# Epoch 974/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0214 - val_loss: 0.0928
# Epoch 975/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0214 - val_loss: 0.0920
# Epoch 976/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0215 - val_loss: 0.0927
# Epoch 977/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0216 - val_loss: 0.0923
# Epoch 978/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0222 - val_loss: 0.0924
# Epoch 979/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0231 - val_loss: 0.0928
# Epoch 980/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0225 - val_loss: 0.0924
# Epoch 981/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0240 - val_loss: 0.0936
# Epoch 982/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0240 - val_loss: 0.0927
# Epoch 983/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0230 - val_loss: 0.0926
# Epoch 984/1024
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0222 - val_loss: 0.0922
# Epoch 985/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0216 - val_loss: 0.0929
# Epoch 986/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0216 - val_loss: 0.0927
# Epoch 987/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0215 - val_loss: 0.0926
# Epoch 988/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0210 - val_loss: 0.0924
# Epoch 989/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0209 - val_loss: 0.0922
# Epoch 990/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0213 - val_loss: 0.0921
# Epoch 991/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0210 - val_loss: 0.0923
# Epoch 992/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0215 - val_loss: 0.0928
# Epoch 993/1024
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0224 - val_loss: 0.0924
# Epoch 994/1024
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0217 - val_loss: 0.0923
# Epoch 995/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0210 - val_loss: 0.0916
# Epoch 996/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0212 - val_loss: 0.0928
# Epoch 997/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0208 - val_loss: 0.0919
# Epoch 998/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0205 - val_loss: 0.0919
# Epoch 999/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0203 - val_loss: 0.0922
# Epoch 1000/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0201 - val_loss: 0.0924
# Epoch 1001/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0202 - val_loss: 0.0921
# Epoch 1002/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0202 - val_loss: 0.0925
# Epoch 1003/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0201 - val_loss: 0.0925
# Epoch 1004/1024
# 10/10 [==============================] - 1s 119ms/step - loss: 0.0200 - val_loss: 0.0920
# Epoch 1005/1024
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0201 - val_loss: 0.0918
# Epoch 1006/1024
# 10/10 [==============================] - 1s 120ms/step - loss: 0.0203 - val_loss: 0.0926
# Epoch 1007/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0203 - val_loss: 0.0915
# Epoch 1008/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0204 - val_loss: 0.0922
# Epoch 1009/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0203 - val_loss: 0.0928
# Epoch 1010/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0202 - val_loss: 0.0918
# Epoch 1011/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0201 - val_loss: 0.0927
# Epoch 1012/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0202 - val_loss: 0.0917
# Epoch 1013/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0205 - val_loss: 0.0925
# Epoch 1014/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0208 - val_loss: 0.0918
# Epoch 1015/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0207 - val_loss: 0.0925
# Epoch 1016/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0208 - val_loss: 0.0925
# Epoch 1017/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0211 - val_loss: 0.0924
# Epoch 1018/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0211 - val_loss: 0.0919
# Epoch 1019/1024
# 10/10 [==============================] - 1s 115ms/step - loss: 0.0206 - val_loss: 0.0924
# Epoch 1020/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0205 - val_loss: 0.0923
# Epoch 1021/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0206 - val_loss: 0.0921
# Epoch 1022/1024
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0206 - val_loss: 0.0919
# Epoch 1023/1024
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0210 - val_loss: 0.0927
# Epoch 1024/1024
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0214 - val_loss: 0.0920
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0887
# Reconstruction error on test set: 0.08866816014051437

# %%
# Plot the training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot the reconstruction error for both training and test sets
reconstruction_error_train = autoencoder.evaluate(X_train, X_train)
print("Reconstruction error on training set:", reconstruction_error_train)
# Evaluate the autoencoder on the test set
reconstruction_error_test = autoencoder.evaluate(X_test, X_test)
print("Reconstruction error on test set:", reconstruction_error_test)
plt.bar(['Training', 'Test'], [reconstruction_error_train, reconstruction_error_test])
plt.title('Reconstruction Error')
plt.ylabel('Loss')
plt.show()
# Out:
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0209
# Reconstruction error on training set: 0.02086331881582737
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0887
# Reconstruction error on test set: 0.08866816014051437

# %%
labels = np.array(labels)
unique_labels = np.unique(labels)
print(unique_labels)
# Out:
# ['arhar' 'bajra' 'barley' 'gram' 'jowar' 'maize' 'ragi' 'rice' 'urad'
#  'wheat']

# %%
# Map each label to a numerical value
label_mapping = {'jowar': 0, 'rice': 1, 'wheat': 2, 'arhar':3, 'bajra':4, 'barley':5, 'gram':6,'maize':7, 'ragi':8, 'urad':9}

# Convert labels to numerical values
numerical_labels = np.array([label_mapping[label] for label in labels])

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(df_concatenated.values, numerical_labels, test_size=0.2, random_state=42)

# Further split the training data into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=42)

# Define the encoder model
encoder_model = Model(inputs=input_layer_train, outputs=encoding_layer3)

# Extract features from the training, validation, and test sets
encoded_train = encoder_model.predict(X_train)
encoded_val = encoder_model.predict(X_val)
encoded_test = encoder_model.predict(X_test)

# Now you can use these encoded representations for further classification tasks
inputs = Input(shape=(encoded_train.shape[1],))
x = Dense(64, activation='relu')(inputs)
xy = Dense(32, activation='relu')(x)
outputs = Dense(10, activation='softmax')(xy)

classifier_model = Model(inputs=inputs, outputs=outputs)

# Compile the classifier model
classifier_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the classifier model
classifier_history = classifier_model.fit(encoded_train, y_train, epochs=300, validation_data=(encoded_val, y_val))

# Evaluate the classifier model on the test set
classifier_loss, classifier_accuracy = classifier_model.evaluate(encoded_test, y_test)
print("Classifier accuracy on test set:", classifier_accuracy)
# Out:
# 10/10 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 23ms/step
# 3/3 [==============================] - 0s 24ms/step
# Epoch 1/100
# 10/10 [==============================] - 1s 29ms/step - loss: 2.1839 - accuracy: 0.2848 - val_loss: 2.0789 - val_accuracy: 0.5143
# Epoch 2/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.9833 - accuracy: 0.4401 - val_loss: 1.9491 - val_accuracy: 0.4286
# Epoch 3/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.8223 - accuracy: 0.4013 - val_loss: 1.8359 - val_accuracy: 0.4286
# Epoch 4/100
# 10/10 [==============================] - 0s 10ms/step - loss: 1.6728 - accuracy: 0.4887 - val_loss: 1.7434 - val_accuracy: 0.5429
# Epoch 5/100
# 10/10 [==============================] - 0s 10ms/step - loss: 1.5374 - accuracy: 0.5405 - val_loss: 1.6613 - val_accuracy: 0.5714
# Epoch 6/100
# 10/10 [==============================] - 0s 10ms/step - loss: 1.4118 - accuracy: 0.5534 - val_loss: 1.5921 - val_accuracy: 0.6000
# Epoch 7/100
# 10/10 [==============================] - 0s 9ms/step - loss: 1.2919 - accuracy: 0.6084 - val_loss: 1.5177 - val_accuracy: 0.6000
# Epoch 8/100
# 10/10 [==============================] - 0s 10ms/step - loss: 1.1829 - accuracy: 0.6505 - val_loss: 1.4700 - val_accuracy: 0.5714
# Epoch 9/100
# 10/10 [==============================] - 0s 9ms/step - loss: 1.0775 - accuracy: 0.7087 - val_loss: 1.4018 - val_accuracy: 0.6000
# Epoch 10/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.9873 - accuracy: 0.7411 - val_loss: 1.3694 - val_accuracy: 0.6000
# Epoch 11/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.9048 - accuracy: 0.7508 - val_loss: 1.3618 - val_accuracy: 0.6000
# Epoch 12/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.8323 - accuracy: 0.7767 - val_loss: 1.3075 - val_accuracy: 0.6000
# Epoch 13/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7696 - accuracy: 0.7832 - val_loss: 1.2649 - val_accuracy: 0.6000
# Epoch 14/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7159 - accuracy: 0.7832 - val_loss: 1.2256 - val_accuracy: 0.6000
# Epoch 15/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6734 - accuracy: 0.7929 - val_loss: 1.1583 - val_accuracy: 0.6000
# Epoch 16/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6286 - accuracy: 0.8026 - val_loss: 1.1456 - val_accuracy: 0.6000
# Epoch 17/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5983 - accuracy: 0.8058 - val_loss: 1.1106 - val_accuracy: 0.6000
# Epoch 18/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5614 - accuracy: 0.8220 - val_loss: 1.1029 - val_accuracy: 0.6000
# Epoch 19/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.5355 - accuracy: 0.8317 - val_loss: 1.1012 - val_accuracy: 0.6000
# Epoch 20/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.5100 - accuracy: 0.8447 - val_loss: 1.0551 - val_accuracy: 0.6286
# Epoch 21/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.4845 - accuracy: 0.8447 - val_loss: 1.0318 - val_accuracy: 0.6286
# Epoch 22/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.4679 - accuracy: 0.8576 - val_loss: 1.0327 - val_accuracy: 0.6286
# Epoch 23/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.4424 - accuracy: 0.8738 - val_loss: 1.0380 - val_accuracy: 0.6286
# Epoch 24/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.4205 - accuracy: 0.8641 - val_loss: 1.0709 - val_accuracy: 0.6286
# Epoch 25/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.4059 - accuracy: 0.8770 - val_loss: 1.0127 - val_accuracy: 0.6286
# Epoch 26/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.3954 - accuracy: 0.8835 - val_loss: 0.9613 - val_accuracy: 0.6286
# Epoch 27/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3708 - accuracy: 0.8900 - val_loss: 1.0262 - val_accuracy: 0.6286
# Epoch 28/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.3597 - accuracy: 0.9061 - val_loss: 0.9859 - val_accuracy: 0.6286
# Epoch 29/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.3483 - accuracy: 0.9029 - val_loss: 0.9705 - val_accuracy: 0.6286
# Epoch 30/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.3350 - accuracy: 0.9061 - val_loss: 1.0315 - val_accuracy: 0.6286
# Epoch 31/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.3202 - accuracy: 0.9159 - val_loss: 0.9708 - val_accuracy: 0.6286
# Epoch 32/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.3030 - accuracy: 0.9256 - val_loss: 1.0191 - val_accuracy: 0.6000
# Epoch 33/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.2927 - accuracy: 0.9223 - val_loss: 0.9966 - val_accuracy: 0.6286
# Epoch 34/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2820 - accuracy: 0.9288 - val_loss: 0.9959 - val_accuracy: 0.6286
# Epoch 35/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2710 - accuracy: 0.9353 - val_loss: 1.0217 - val_accuracy: 0.6000
# Epoch 36/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2595 - accuracy: 0.9482 - val_loss: 0.9826 - val_accuracy: 0.6000
# Epoch 37/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2509 - accuracy: 0.9450 - val_loss: 1.0144 - val_accuracy: 0.6000
# Epoch 38/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2416 - accuracy: 0.9482 - val_loss: 0.9799 - val_accuracy: 0.6286
# Epoch 39/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2325 - accuracy: 0.9450 - val_loss: 1.0214 - val_accuracy: 0.6000
# Epoch 40/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2216 - accuracy: 0.9579 - val_loss: 0.9933 - val_accuracy: 0.6000
# Epoch 41/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2189 - accuracy: 0.9579 - val_loss: 1.0246 - val_accuracy: 0.6000
# Epoch 42/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2129 - accuracy: 0.9579 - val_loss: 1.0254 - val_accuracy: 0.6286
# Epoch 43/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2089 - accuracy: 0.9612 - val_loss: 1.0187 - val_accuracy: 0.6000
# Epoch 44/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1949 - accuracy: 0.9709 - val_loss: 1.0326 - val_accuracy: 0.6286
# Epoch 45/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1856 - accuracy: 0.9709 - val_loss: 1.0416 - val_accuracy: 0.6286
# Epoch 46/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1798 - accuracy: 0.9741 - val_loss: 1.0361 - val_accuracy: 0.6286
# Epoch 47/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1783 - accuracy: 0.9709 - val_loss: 1.0611 - val_accuracy: 0.6286
# Epoch 48/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1753 - accuracy: 0.9741 - val_loss: 1.0431 - val_accuracy: 0.6286
# Epoch 49/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1600 - accuracy: 0.9871 - val_loss: 1.0395 - val_accuracy: 0.6571
# Epoch 50/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1565 - accuracy: 0.9838 - val_loss: 1.0170 - val_accuracy: 0.6571
# Epoch 51/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1508 - accuracy: 0.9806 - val_loss: 1.0635 - val_accuracy: 0.6286
# Epoch 52/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1437 - accuracy: 0.9806 - val_loss: 1.0345 - val_accuracy: 0.6857
# Epoch 53/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1383 - accuracy: 0.9871 - val_loss: 1.0796 - val_accuracy: 0.6286
# Epoch 54/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1372 - accuracy: 0.9871 - val_loss: 1.0511 - val_accuracy: 0.6286
# Epoch 55/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1328 - accuracy: 0.9838 - val_loss: 1.0668 - val_accuracy: 0.6571
# Epoch 56/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1270 - accuracy: 0.9871 - val_loss: 1.1132 - val_accuracy: 0.6286
# Epoch 57/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1248 - accuracy: 0.9871 - val_loss: 1.0901 - val_accuracy: 0.6571
# Epoch 58/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1176 - accuracy: 0.9871 - val_loss: 1.1002 - val_accuracy: 0.6571
# Epoch 59/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1131 - accuracy: 0.9871 - val_loss: 1.0772 - val_accuracy: 0.6571
# Epoch 60/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1114 - accuracy: 0.9935 - val_loss: 1.1296 - val_accuracy: 0.6571
# Epoch 61/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1055 - accuracy: 0.9935 - val_loss: 1.1167 - val_accuracy: 0.6571
# Epoch 62/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1041 - accuracy: 0.9935 - val_loss: 1.1029 - val_accuracy: 0.6857
# Epoch 63/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0988 - accuracy: 0.9968 - val_loss: 1.1205 - val_accuracy: 0.6571
# Epoch 64/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0981 - accuracy: 0.9871 - val_loss: 1.1337 - val_accuracy: 0.6286
# Epoch 65/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0958 - accuracy: 0.9935 - val_loss: 1.1330 - val_accuracy: 0.6571
# Epoch 66/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0901 - accuracy: 1.0000 - val_loss: 1.1287 - val_accuracy: 0.6571
# Epoch 67/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0886 - accuracy: 0.9968 - val_loss: 1.1461 - val_accuracy: 0.6571
# Epoch 68/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0842 - accuracy: 0.9968 - val_loss: 1.1637 - val_accuracy: 0.6571
# Epoch 69/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0806 - accuracy: 0.9968 - val_loss: 1.1672 - val_accuracy: 0.6571
# Epoch 70/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0777 - accuracy: 0.9968 - val_loss: 1.1644 - val_accuracy: 0.6571
# Epoch 71/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0750 - accuracy: 0.9968 - val_loss: 1.1990 - val_accuracy: 0.6571
# Epoch 72/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0726 - accuracy: 0.9968 - val_loss: 1.1740 - val_accuracy: 0.6857
# Epoch 73/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0698 - accuracy: 0.9968 - val_loss: 1.1738 - val_accuracy: 0.6857
# Epoch 74/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0675 - accuracy: 1.0000 - val_loss: 1.2087 - val_accuracy: 0.6571
# Epoch 75/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0660 - accuracy: 1.0000 - val_loss: 1.2078 - val_accuracy: 0.6571
# Epoch 76/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0628 - accuracy: 1.0000 - val_loss: 1.2092 - val_accuracy: 0.6571
# Epoch 77/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0616 - accuracy: 1.0000 - val_loss: 1.2172 - val_accuracy: 0.6571
# Epoch 78/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0598 - accuracy: 1.0000 - val_loss: 1.2194 - val_accuracy: 0.6571
# Epoch 79/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0575 - accuracy: 0.9968 - val_loss: 1.2338 - val_accuracy: 0.6571
# Epoch 80/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0551 - accuracy: 1.0000 - val_loss: 1.2394 - val_accuracy: 0.6571
# Epoch 81/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0545 - accuracy: 1.0000 - val_loss: 1.2587 - val_accuracy: 0.6571
# Epoch 82/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0541 - accuracy: 1.0000 - val_loss: 1.2404 - val_accuracy: 0.7143
# Epoch 83/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0503 - accuracy: 1.0000 - val_loss: 1.2798 - val_accuracy: 0.6571
# Epoch 84/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0490 - accuracy: 1.0000 - val_loss: 1.2834 - val_accuracy: 0.6571
# Epoch 85/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0478 - accuracy: 1.0000 - val_loss: 1.2896 - val_accuracy: 0.6571
# Epoch 86/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0464 - accuracy: 1.0000 - val_loss: 1.2722 - val_accuracy: 0.7143
# Epoch 87/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0440 - accuracy: 1.0000 - val_loss: 1.2787 - val_accuracy: 0.6857
# Epoch 88/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0441 - accuracy: 1.0000 - val_loss: 1.3006 - val_accuracy: 0.6571
# Epoch 89/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0434 - accuracy: 1.0000 - val_loss: 1.3102 - val_accuracy: 0.6571
# Epoch 90/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0412 - accuracy: 1.0000 - val_loss: 1.3124 - val_accuracy: 0.7143
# Epoch 91/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0401 - accuracy: 1.0000 - val_loss: 1.3353 - val_accuracy: 0.6571
# Epoch 92/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0388 - accuracy: 1.0000 - val_loss: 1.3230 - val_accuracy: 0.7143
# Epoch 93/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0373 - accuracy: 1.0000 - val_loss: 1.3289 - val_accuracy: 0.6857
# Epoch 94/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0364 - accuracy: 1.0000 - val_loss: 1.3445 - val_accuracy: 0.7143
# Epoch 95/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0352 - accuracy: 1.0000 - val_loss: 1.3488 - val_accuracy: 0.7143
# Epoch 96/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0340 - accuracy: 1.0000 - val_loss: 1.3769 - val_accuracy: 0.6571
# Epoch 97/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0332 - accuracy: 1.0000 - val_loss: 1.3388 - val_accuracy: 0.7429
# Epoch 98/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0323 - accuracy: 1.0000 - val_loss: 1.3721 - val_accuracy: 0.6571
# Epoch 99/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0311 - accuracy: 1.0000 - val_loss: 1.3861 - val_accuracy: 0.6571
# Epoch 100/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0302 - accuracy: 1.0000 - val_loss: 1.3675 - val_accuracy: 0.7143
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8356 - accuracy: 0.7442
# Classifier accuracy on test set: 0.7441860437393188

# %%
# Plot training loss
plt.plot(classifier_history.history['loss'], label='Training Loss')
# Plot validation loss
plt.plot(classifier_history.history['val_loss'], label='Validation Loss')
plt.title('Classifier Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training accuracy
plt.plot(classifier_history.history['accuracy'], label='Training Accuracy')
# Plot validation accuracy
plt.plot(classifier_history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Classifier Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Make predictions on the test data
predictions = classifier_model.predict(encoded_test)

# Convert predicted probabilities into class labels
predicted_labels = np.argmax(predictions, axis=1)

accuracy = np.mean(predicted_labels == y_test)

print("Accuracy:", accuracy)
# Out:
# 3/3 [==============================] - 0s 4ms/step
# Accuracy: 0.7441860465116279

# %%
def predict_categories_from_urls(urls, encoder_model, classifier_model):
    # Load and adjust the data
    datas = load_and_adjust_data(urls, 180)

    # Convert each DataFrame to a single row
    single_row_datas = [append_rows_to_single_row(data) for data in datas]

    # Concatenate the single-row DataFrames
    datas_concatenated = pd.concat(single_row_datas, axis=0)

    # Use the trained encoder model to extract features from the reconstructed data
    encoded_reconstructed_data = encoder_model.predict(datas_concatenated.values.reshape(datas_concatenated.shape[0], datas_concatenated.shape[1], 1))

    # Make predictions on the reconstructed data using the classifier model
    predictions = classifier_model.predict(encoded_reconstructed_data)

    # Convert predicted probabilities into class labels
    predicted_labels = np.argmax(predictions, axis=1)

    # Map the class labels to their corresponding categories
    category_mapping = {0: 'jowar', 1: 'rice', 2: 'wheat',3:'arhar',4: 'bajra',5: 'barley',6: 'gram',7: 'maize',8: 'ragi',9:'urad'}
    predicted_categories = [category_mapping[label] for label in predicted_labels]

    return predicted_categories

# %%
test_urls = ['/content/drive/MyDrive/ACPS_Project/Modified for model/Adilabad_2015_wheat_10-05_weather.xlsx']
predicted_categories = predict_categories_from_urls(test_urls, encoder_model, classifier_model)
print("Predicted categories:", predicted_categories)
# Out:
# 1/1 [==============================] - 0s 393ms/step
# 1/1 [==============================] - 0s 18ms/step
# Predicted categories: ['wheat']

# %%
encoder_model.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 1260, 1)]         0
#
#  conv1d_8 (Conv1D)           (None, 1258, 512)         2048
#
#  conv1d_9 (Conv1D)           (None, 1256, 512)         786944
#
#  conv1d_10 (Conv1D)          (None, 1252, 128)         327808
#
#  conv1d_11 (Conv1D)          (None, 1248, 128)         82048
#
#  flatten_2 (Flatten)         (None, 159744)            0
#
#  dense_18 (Dense)            (None, 512)               81789440
#
#  dense_19 (Dense)            (None, 256)               131328
#
#  dense_20 (Dense)            (None, 128)               32896
#
# =================================================================
# Total params: 83152512 (317.20 MB)
# Trainable params: 83152512 (317.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
classifier_model.summary()
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 128)]             0
#
#  dense_24 (Dense)            (None, 64)                8256
#
#  dense_25 (Dense)            (None, 32)                2080
#
#  dense_26 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 10666 (41.66 KB)
# Trainable params: 10666 (41.66 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
autoencoder.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 1260, 1)]         0
#
#  conv1d_8 (Conv1D)           (None, 1258, 512)         2048
#
#  conv1d_9 (Conv1D)           (None, 1256, 512)         786944
#
#  conv1d_10 (Conv1D)          (None, 1252, 128)         327808
#
#  conv1d_11 (Conv1D)          (None, 1248, 128)         82048
#
#  flatten_2 (Flatten)         (None, 159744)            0
#
#  dense_18 (Dense)            (None, 512)               81789440
#
#  dense_19 (Dense)            (None, 256)               131328
#
#  dense_20 (Dense)            (None, 128)               32896
#
#  dense_21 (Dense)            (None, 256)               33024
#
#  dense_22 (Dense)            (None, 512)               131584
#
#  dense_23 (Dense)            (None, 1260)              646380
#
# =================================================================
# Total params: 83963500 (320.30 MB)
# Trainable params: 83963500 (320.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
